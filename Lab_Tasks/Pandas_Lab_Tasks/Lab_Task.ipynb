# %%
import pandas as pd

# %%
# Load dataset
file_path = r"D:\Huawei-HCCDA-AI-Corvit-Mardan\HCCDA-AI-Course\Datasets\Titanic3.csv"
df = pd.read_csv(file_path)

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
# 1309     NaN       NaN                                              NaN
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
# Task 2: View first 5 rows
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
# Task 3: Dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   float64
#  1   survived   1309 non-null   float64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   float64
#  6   parch      1309 non-null   float64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(7), object(7)
# memory usage: 143.4+ KB

# %%
# Task 4: Describe numerical data
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
# Task 5: Count missing values
df.isnull().sum()
# Out:
# pclass          1
# survived        1
# name            1
# sex             1
# age           264
# sibsp           1
# parch           1
# ticket          1
# fare            2
# cabin        1015
# embarked        3
# boat          824
# body         1189
# home.dest     565
# dtype: int64

# %%
# Task 6: Filter by Gender
df[df['sex'] == 'male']
# Out:
#       pclass  survived                                  name   sex      age  \
# 1        1.0       1.0        Allison, Master. Hudson Trevor  male   0.9167
# 3        1.0       0.0  Allison, Mr. Hudson Joshua Creighton  male  30.0000
# 5        1.0       1.0                   Anderson, Mr. Harry  male  48.0000
# 7        1.0       0.0                Andrews, Mr. Thomas Jr  male  39.0000
# 9        1.0       0.0               Artagaveytia, Mr. Ramon  male  71.0000
# ...      ...       ...                                   ...   ...      ...
# 1302     3.0       0.0                     Yousif, Mr. Wazli  male      NaN
# 1303     3.0       0.0                 Yousseff, Mr. Gerious  male      NaN
# 1306     3.0       0.0             Zakarian, Mr. Mapriededer  male  26.5000
# 1307     3.0       0.0                   Zakarian, Mr. Ortin  male  27.0000
# 1308     3.0       0.0                    Zimmerman, Mr. Leo  male  29.0000
#
# ...

# %%
# Task 7: Survival rate
survival_rate = (df['survived'].sum() / len(df)) * 100
print(f"Survival rate: {survival_rate:.2f}%")
# Out:
# Survival rate: 38.17%

# %%
# Task 8: Average age
print(f"Average age: {df['age'].mean():.2f}")
# Out:
# Average age: 29.88

# %%
# Task 9: Group by class and average fare
print(df.groupby('pclass')['fare'].mean())
# Out:
# pclass
# 1.0    87.508992
# 2.0    21.179196
# 3.0    13.302889
# Name: fare, dtype: float64

# %%
# Task 10: Top 10 by fare
df.sort_values('fare', ascending=False).head(10)
# Out:
#      pclass  survived                                               name  \
# 302     1.0       1.0                                   Ward, Miss. Anna
# 49      1.0       1.0                 Cardeza, Mr. Thomas Drake Martinez
# 50      1.0       1.0  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 183     1.0       1.0                             Lesurer, Mr. Gustave J
# 116     1.0       1.0                Fortune, Mrs. Mark (Mary McDougald)
# 111     1.0       1.0                     Fortune, Miss. Alice Elizabeth
# 115     1.0       0.0                                  Fortune, Mr. Mark
# 114     1.0       0.0                     Fortune, Mr. Charles Alexander
# 113     1.0       1.0                         Fortune, Miss. Mabel Helen
# 112     1.0       1.0                         Fortune, Miss. Ethel Flora
#
#         sex   age  sibsp  parch    ticket      fare        cabin embarked  \
# 302  female  35.0    0.0    0.0  PC 17755  512.3292          NaN        C
# ...

# %%
#Check How Much Data is Missing in age Column
missing_age = df['age'].isnull().sum()
print(f"Missing age: {missing_age}")
# Out:
# Missing age: 264

# %%
#print age column with Name
print(df[['name', 'age']])
# Out:
#                                                  name      age
# 0                       Allen, Miss. Elisabeth Walton  29.0000
# 1                      Allison, Master. Hudson Trevor   0.9167
# 2                        Allison, Miss. Helen Loraine   2.0000
# 3                Allison, Mr. Hudson Joshua Creighton  30.0000
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  25.0000
# ...                                               ...      ...
# 1305                            Zabour, Miss. Thamine      NaN
# 1306                        Zakarian, Mr. Mapriededer  26.5000
# 1307                              Zakarian, Mr. Ortin  27.0000
# 1308                               Zimmerman, Mr. Leo  29.0000
# 1309                                              NaN      NaN
#
# [1310 rows x 2 columns]

# %%
df['age'] = df['age'].fillna(df['age'].mean())

# %%
# Check again how much data is missing in age column after filling
missing_age_after_fill = df['age'].isnull().sum()
print(f"Missing age after fill: {missing_age_after_fill}")
# Out:
# Missing age after fill: 0

# %%
# Print the updated DataFrame
df.head(20)
# Out:
#     pclass  survived                                               name  \
# 0      1.0       1.0                      Allen, Miss. Elisabeth Walton
# 1      1.0       1.0                     Allison, Master. Hudson Trevor
# 2      1.0       0.0                       Allison, Miss. Helen Loraine
# 3      1.0       0.0               Allison, Mr. Hudson Joshua Creighton
# 4      1.0       0.0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5      1.0       1.0                                Anderson, Mr. Harry
# 6      1.0       1.0                  Andrews, Miss. Kornelia Theodosia
# 7      1.0       0.0                             Andrews, Mr. Thomas Jr
# 8      1.0       1.0      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9      1.0       0.0                            Artagaveytia, Mr. Ramon
# 10     1.0       0.0                             Astor, Col. John Jacob
# 11     1.0       1.0  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...
